# %%
import pandas as pd
import sqlite3
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
sns.set(style='whitegrid')

# %%
# Define the file path
csv_path = '../data/menu.csv'

# Read the CSV file into a DataFrame
data = pd.read_csv(csv_path)

# Display the first 5 rows
data.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
# Connect to SQLite database (it will be created if it doesn't exist)
conn = sqlite3.connect('../db/mcdonalds.db')

# Store the DataFrame as a SQL table
data.to_sql('mcdonalds_nutrition', conn, if_exists='replace', index=False)

# Confirm the table is stored
print("Table 'mcdonalds_nutrition' has been saved to the database.")
# Out:
# Table 'mcdonalds_nutrition' has been saved to the database.

# %%
query = "SELECT * FROM mcdonalds_nutrition"
df = pd.read_sql(query, conn)
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
print("Dataset Shape:", df.shape)
df.info()
df.describe()
# Out:
# Dataset Shape: (260, 24)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %%
max_sodium_idx = df['Sodium'].idxmax()
df.loc[[max_sodium_idx], ['Item', 'Sodium']]
# Out:
#                             Item  Sodium
# 82  Chicken McNuggets (40 piece)    3600

# %%
plt.figure(figsize=(14, 6))
sns.swarmplot(x='Category', y='Sodium', data=df)
plt.xticks(rotation=45)
plt.title('Sodium Content by Food Category')
plt.tight_layout()
plt.show()
# Out:
# c:\Users\Pratishtha Srivastav\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 22.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Pratishtha Srivastav\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 40.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Pratishtha Srivastav\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 14.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.jointplot(x='Protein', y='Total Fat', data=df, kind='scatter')
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.boxplot(y='Sugars', data=df)
plt.title('Sugar Content Distribution')
plt.show()

# %% [markdown]
# ### Summary
#
# - The dataset includes nutritional facts for McDonald's menu items.
# - Stored the data into an SQLite database using Python.
# - Found that **Chicken McNuggets (40 pieces)** has the highest sodium content (3600 mg).
# - Protein and Total Fat are **strongly positively correlated**.
# - Sugar content has **high outliers**, likely from desserts or sweet drinks.
